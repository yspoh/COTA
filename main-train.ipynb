# %%
from utils import *
from run import *

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
os.environ["TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S"]="0"

# Ray Tune on Multiple selected GPUs
# os.environ["CUDA_VISIBLE_DEVICES"]="1,3,4,5,6,8,9"
os.environ["CUDA_VISIBLE_DEVICES"]="0,1"
gpu_per_task = 0.5 # 0.5 means each task will use 0.5 GPU
# CDR task
source_domain = "movie"
target_domain = "music"
# beta = 20 or 50 or 80
ratio = "20"
# Hyparameter Sensitivity of main model
lrlist= [0.1, 0.01, 0.001]
# clusterlist = [0,128,256,512,768]
clusterlist = [128, 256]
# num_expert = [2,8,16,32,64]
num_expert = [8]
# taulist = [0.1, 0.5, 1, 5, 10]
taulist = [1]

# True use source prototype mapping, false for ablation study
usepmap = True

# abandoned
wdlist = [0]
infolist = [0]

main(source_domain, target_domain, ratio, usepmap, num_expert, taulist,
 lrlist, wdlist, infolist, clusterlist, device, gpus_per_trial=gpu_per_task, cpus_per_trial=1)
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2026-04-17 12:56:39</td></tr>
# <tr><td>Running for: </td><td>00:01:34.43        </td></tr>
# <tr><td>Memory:      </td><td>204.0/345.8 GiB    </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using AsyncHyperBand: num_stopped=0<br>Bracket: Iter 40.000: None<br>Logical resource usage: 4.0/64 CPUs, 2.0/2 GPUs (0.0/1.0 accelerator_type:G)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# ...
